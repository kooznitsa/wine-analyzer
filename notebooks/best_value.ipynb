# %%
import pandas as pd
import numpy as np
import re
from ast import literal_eval
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib notebook

# %%
file = '../data/spain-red'
df = pd.read_csv(file + '.csv', converters={'foods': literal_eval, 'highlights': literal_eval})

# %%
diacritics = {'&#237;': 'í', '&#243;': 'ó', '&#250;': 'ú', '&#241;': 'ñ', '&#232;': 'è', \
    '&#8364;': '€', '&#193;': 'Á', '&#192;': 'À', '&#233;': 'é', '&#224;': 'à', \
    '&#239;': 'ï', '&#231;': 'ç', '&#193;': 'Á', '&#252;': 'ü', '&#225;': 'á', '&#186;': 'º', \
    '&#244;': 'ô', '&#8217;': '’', '&#960;': 'π', '&#210;': 'Ò'}
df.replace(diacritics, regex=True, inplace=True)
df['winery'] = df['winery'].apply(lambda x: re.sub(r'((?<=[a-z_à-ÿ])[A-Z]|(?<!\A)[A-Z](?=[a-z_à-ÿ]))', r' \1', x))
df['vintage'] = df['vintage'].apply(lambda x: re.sub(r'((?<=[a-z_à-ÿ])[A-Z]|(?<!\A)[A-Z](?=[a-z_à-ÿ]))', r' \1', x))
df['region'] = df['region'].apply(lambda x: re.sub(r'((?<=[a-z_à-ÿ])[A-Z]|(?<!\A)[A-Z](?=[a-z_à-ÿ]))', r' \1', x))
df['vintage'] = df['vintage'].apply(lambda x: re.sub(r"(\S)\(", r'\1 (', x))
df['vintage'] = df['vintage'].apply(lambda x: re.sub('\(\s*(.*?)\s*\)', r'(\1)', x))
df['vintage'] = df['vintage'].apply(lambda x: re.sub(r"([0-9]+(\.[0-9]+)?)",r" \1 ", x).strip())
df['vintage'] = df['vintage'].replace(r'\s+', ' ', regex=True)

numeric_columns = ['year', 'rating', 'ratings_count', 'country_rank', 'region_rank', \
                   'winery_rank', 'global_rank', 'alcohol', 'body', 'acidity', 'price']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

df = df.drop(['drink_from', 'drink_until'], axis = 1)

# %%
df.describe()
# Out:
#             rating  ratings_count  country_rank  region_rank  winery_rank  \
# count  2017.000000    2017.000000   2017.000000  2017.000000  2017.000000
# mean      4.147992     744.478433      3.930590     5.692117    15.629152
# std       0.244010    1714.883180      3.456955     5.452801    12.844511
# min       3.700000      25.000000      1.000000     1.000000     1.000000
# 25%       3.900000      86.000000      1.000000     2.000000     6.000000
# 50%       4.100000     227.000000      3.000000     4.000000    12.000000
# 75%       4.300000     659.000000      5.000000     8.000000    22.000000
# max       4.900000   32378.000000     22.000000    38.000000    81.000000
#
#        global_rank      alcohol         body      acidity        price
# count  2017.000000  1656.000000  1900.000000  1900.000000  2013.000000
# mean      4.140803    14.081582     4.271579     2.963158    87.068867
# std       3.426670     1.634316     0.507897     0.188424   234.235746
# min       1.000000     0.000000     3.000000     2.000000     4.900000
# 25%       1.000000    14.000000     4.000000     3.000000    18.950000
# 50%       3.000000    14.500000     4.000000     3.000000    31.130000
# 75%       6.000000    14.500000     5.000000     3.000000    61.950000
# max      20.000000    16.500000     5.000000     3.000000  3404.940000

# %%
# Best value wine: cheaper wine with rating more than median (4.1) and number of ratings more than median value (227).
# Best-value wines are 15.8% (318) of all wines in the dataset (2017).

best_value = df[(df['price'] < 100) & (df['rating'] > 4.1) & (df['ratings_count'] > 227)]
best_value.describe()
# Out:
#            rating  ratings_count  country_rank  region_rank  winery_rank  \
# count  318.000000     318.000000    318.000000   318.000000   318.000000
# mean     4.307233    1337.666667      1.081761     2.097484    11.789308
# std      0.106468    1828.049177      0.274432     1.384887     9.887200
# min      4.200000     228.000000      1.000000     1.000000     1.000000
# 25%      4.200000     379.500000      1.000000     1.000000     4.000000
# 50%      4.300000     653.000000      1.000000     2.000000     9.000000
# 75%      4.400000    1339.250000      1.000000     3.000000    16.750000
# max      4.700000   16395.000000      2.000000     6.000000    46.000000
#
#        global_rank     alcohol        body     acidity       price
# count   318.000000  296.000000  302.000000  302.000000  318.000000
# mean      1.279874   14.137162    4.334437    2.966887   49.219277
# std       0.449645    1.944424    0.479555    0.179228   21.600254
# min       1.000000    0.000000    3.000000    2.000000    7.300000
# 25%       1.000000   14.000000    4.000000    3.000000   31.687500
# 50%       1.000000   14.500000    4.000000    3.000000   44.980000
# 75%       2.000000   14.500000    5.000000    3.000000   63.500000
# max       2.000000   16.500000    5.000000    3.000000   99.500000

# %%
full_bodied = best_value[(best_value['alcohol'] >= 13.5)]
full_bodied.describe()
# Out:
#            rating  ratings_count  country_rank  region_rank  winery_rank  \
# count  279.000000     279.000000    279.000000   279.000000   279.000000
# mean     4.307527    1405.139785      1.068100     2.064516    11.691756
# std      0.108525    1875.240836      0.252371     1.350245     9.890678
# min      4.200000     231.000000      1.000000     1.000000     1.000000
# 25%      4.200000     395.500000      1.000000     1.000000     4.000000
# 50%      4.300000     695.000000      1.000000     2.000000     9.000000
# 75%      4.400000    1501.500000      1.000000     3.000000    16.000000
# max      4.700000   16395.000000      2.000000     6.000000    46.000000
#
#        global_rank     alcohol        body     acidity       price
# count   279.000000  279.000000  264.000000  264.000000  279.000000
# mean      1.279570   14.449104    4.344697    2.965909   48.770358
# std       0.449594    0.484052    0.484091    0.181807   21.620336
# min       1.000000   13.500000    3.000000    2.000000    7.300000
# 25%       1.000000   14.000000    4.000000    3.000000   31.450000
# 50%       1.000000   14.500000    4.000000    3.000000   44.980000
# 75%       2.000000   14.500000    5.000000    3.000000   62.725000
# max       2.000000   16.500000    5.000000    3.000000   99.500000

# %%
# 88% of best-value wines are full-bodied.
# Any red wine with more than 13.5 percent alcohol is considered a full-bodied wine. 
# Full-bodied wines have more complex flavors and have a richer mouthfeel.

# %%
bv_prices = best_value['price']
bins = [7, 20, 30, 40, 50, 60, 70, 80, 90, 100]
cats = pd.cut(bv_prices, bins)
pd.value_counts(cats)
# Out:
# (30, 40]     63
# (40, 50]     61
# (20, 30]     57
# (50, 60]     39
# (60, 70]     24
# (70, 80]     24
# (90, 100]    20
# (80, 90]     19
# (7, 20]      11
# Name: price, dtype: int64

# %%
pop_prices = best_value[(best_value['price'] >= 30) & (best_value['price'] <= 60)]
pop_prices.describe()
# Out:
#            rating  ratings_count  country_rank  region_rank  winery_rank  \
# count  163.000000     163.000000    163.000000   163.000000   163.000000
# mean     4.306748    1450.331288      1.098160     2.098160    12.601227
# std      0.093709    1781.914916      0.298447     1.370837    10.959262
# min      4.200000     228.000000      1.000000     1.000000     1.000000
# 25%      4.200000     389.000000      1.000000     1.000000     4.000000
# 50%      4.300000     680.000000      1.000000     2.000000     9.000000
# 75%      4.400000    1698.500000      1.000000     3.000000    17.000000
# max      4.600000   10267.000000      2.000000     6.000000    46.000000
#
#        global_rank     alcohol        body     acidity       price
# count   163.000000  155.000000  156.000000  156.000000  163.000000
# mean      1.245399   13.930968    4.391026    2.967949   44.091104
# std       0.431649    2.348765    0.489552    0.176704    8.848998
# min       1.000000    0.000000    4.000000    2.000000   30.430000
# 25%       1.000000   14.000000    4.000000    3.000000   36.300000
# 50%       1.000000   14.500000    4.000000    3.000000   44.410000
# 75%       1.000000   14.500000    5.000000    3.000000   49.925000
# max       2.000000   16.000000    5.000000    3.000000   59.950000

# %%
# 51% of best-value wines cost betweeen 30 and 60 euros.

# %%
bv_wineries = best_value['winery'].value_counts()
bv_wineries.head()
# Out:
# Álvaro Palacios     18
# La Rioja Alta       13
# Clos Mogador        10
# Remírezde Ganuza    10
# Emilio Moro          9
# Name: winery, dtype: int64

# %%
bv_vintages = best_value['vintage'].value_counts()
bv_vintages.head()
# Out:
# Rioja Reserva      16
# Priorat            13
# Finca Dofí         11
# Riberadel Duero    10
# Tinto               9
# Name: vintage, dtype: int64

# %%
bv_years = best_value['year'].value_counts()
bv_years.head()
# Out:
# 2017    53
# 2016    52
# 2015    40
# 2018    37
# 2014    29
# Name: year, dtype: int64

# %%
bv_regions = best_value['region'].value_counts()
bv_regions.head()
# Out:
# Rioja              112
# Riberadel Duero     80
# Priorat             51
# Toro                18
# Castillay León       9
# Name: region, dtype: int64

# %%
# 35% best-value wines are from Rioja.

# %%
for f in df['foods']:
    f.sort()

bv_foods = best_value['foods'].value_counts()
bv_foods.head()
# Out:
# [Beef, Lamb, Poultry, Veal]                    126
# [Beef, Game (deer, venison), Lamb]              98
# [Beef, Game (deer, venison), Lamb, Poultry]     57
# [Beef, Pasta, Poultry, Veal]                    24
# [Beef, Lamb, Poultry]                            4
# Name: foods, dtype: int64

# %%
# 40% of best-value wines foods are "Beef, Lamb, Poultry, Veal".

# %%
bv_styles = best_value['style'].value_counts()
bv_styles.head()
# Out:
# Spanish Rioja Red               116
# Spanish Ribera Del Duero Red     80
# Spanish Priorat Red              51
# Spanish Red                      24
# Spanish Toro Red                 18
# Name: style, dtype: int64

# %%
bv_acidity = best_value['acidity'].value_counts()
bv_acidity
# Out:
# 3.0    292
# 2.0     10
# Name: acidity, dtype: int64

# %%
# 91.8% of best-value wines have acidity of 3.

# Typically, the pH level of a wine ranges from 3 to 4. 
# Red wines with higher acidity are more likely to be a bright ruby color, 
# as the lower pH gives them a red hue. 
# Higher pH, less-acidic red wines can take on a blue or purple hue.

# %%
bv_grapes = best_value['grapes'].value_counts()
bv_grapes
# Out:
# Tempranillo           167
# Garnacha               27
# Shiraz/Syrah           24
# Tinto Fino             17
# Cariñena               12
# Merlot                 10
# Tinta de toro           9
# Cabernet Sauvignon      8
# Tinta del Pais          6
# Grenache                4
# Monastrell              3
# Pinot Noir              2
# Mourvedre               2
# Graciano                2
# Bobal                   2
# Callet                  1
# Garnacha Tintorera      1
# Mencia                  1
# Mazuelo                 1
# Name: grapes, dtype: int64

# %%
# 52.5% of best-values wines are of Tempranillo grapes.
